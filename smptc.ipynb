# %%
# Importation des bibliothèques pandas et numpy 
import pandas as pd
import numpy as np

# %%
# Importation du module smtplib pour la gestion de l'envoi d'e-mails via le protocole SMTP
import smtplib

# Importation des classes MIMEMultipart, MIMEText et MIMEApplication de la bibliothèque email.mime
from email.mime.multipart import MIMEMultipart  # Permet de créer des e-mails avec plusieurs parties
from email.mime.text import MIMEText  # Permet de créer des parties textuelles pour les e-mails
from email.mime.application import MIMEApplication  # Permet de créer des pièces jointes pour les e-mails

# %% [markdown]
# # gestion des mail

# %%
# Importation de la bibliothèque pandas
import pandas as pd

# Lecture des données à partir du fichier Excel "aws.xlsx" et stockage dans un DataFrame pandas
data = pd.read_excel('aws.xlsx')

# Extraction de la colonne 'Adresse e-mail' du DataFrame et stockage dans une liste appelée 'mail'
mail = list(data['Adresse e-mail'])

# %%
for i in mail:
    print(i[-12:])
# Out:
# 9@gmail.com
# ro@gmail.com
# 53@gmail.com
# a3@gmail.com
# 22@gmail.com
# a4@gmail.com
# 19@gmail.com
# 13@gmail.com
# le@gmail.com
# o@gmail.com
# 89@gmail.com
# 00@gmail.com
# 92@gmail.com
# ne@gmail.com
# ie@gmail.com
# sa@gmail.com
# ce@gmail.com
# ie@gmail.com
# 77@gmail.com
# 22@gmail.com
# el@gmail.com
# 72@gmail.com
# lo@gmail.com
# y2@gmail.com
# ua@gmail.com
# sy@gmail.com
# 3@gmail.com
# 21@gmail.com
# @uvci.edu.ci
# an@gmail.com
# in@gmail.com
# 23@gmail.com
# n@gmail.com
# ry@gmail.com
# ak@gmail.com
# @uvci.edu.ci
# l5@gmail.com
# h@gmail.com
# 9@gmail.com
# lo@gmail.com
# 79@gmail.com
# 2@gmail.com
# 0@icloud.com
# hotmail.com
# 07@gmail.com
# ed@gmail.com
# 73@gmail.com
# uvci.edu.ci
# en@gmail.com
# @uvci.edu.ci
# si@gmail.com
# @uvci.edu.ci
# 25icloud.com
# 13@gmail.com
# e@gmail.com
# on@gmail.com
# vc@gmail.com
# 02@gmail.com
# 9@gmail.com
# ou@gmail.com
# ts@gmail.com
# ou@gmail.com
# 17@gmail.com
# e@gmail.com
# 18@gmail.com
# el@gmail.com
# nckdiomande
# aq@gmail.com
# 12@gmail.com
# o5@gmail.com
# 98@gmail.com
# 04@gmail.com
# 39@gmail.com
# @uvci.edu.ci
# be@gmail.com
# 98@gmail.com
# o9@gmail.com
# c1@gmail.com
# te@gmail.com
# r1@gmail.com
# ne@gmail.com
# lo@gmail.com
# 45@gmail.com
# 84&gmail.com
# d@gmail.com
# 0@gmail.com
# u@icloud.com
# 01@gmail.com
# 22@gmail.com
        # Si oui, ajoute l'adresse e-mail à la liste ngmail
        ngmail.append(i)

# Parcours de chaque adresse e-mail filtrée dans la liste ngmail
for i in ngmail:
    # Supprime l'adresse e-mail de la liste d'origine mail
    mail.remove(i)

# %%
ngmail
# Out:
# ['nafanda1990@icloud.com',
#  'Konekadi25icloud.com',
#  'louafranckdiomande ',
#  'AndyKarole384&gmail.com',
#  'cyrilleamou@icloud.com',
#  'Cheikidris@icloud.com',
#  'lineyao65@gmail.coml ']

# %%
ngmail[1]='Konekadi25@icloud.com'
ngmail[2]='louafranckdiomande@gmail.com'
ngmail[3]='AndyKarole384@gmail.com'
ngmail
# Out:
# ['nafanda1990@icloud.com',
#  'Konekadi25@icloud.com',
#  'louafranckdiomande@gmail.com',
#  'AndyKarole384@gmail.com',
#  'cyrilleamou@icloud.com',
#  'Cheikidris@icloud.com',
#  'lineyao65@gmail.coml ']

# %% [markdown]
# # envoi de e-mails

# %%
expediteur ="andiaye.ext@simplon.co"
mot_de_passe ="mhnxtsumvgqxqvhq"
sujet = "Entretien individuel"

# %%
# Définition de l'heure de départ et du compteur
heure = 10
count = 0

# Parcours de chaque adresse e-mail dans la liste mail
for i in mail:
    # Vérifie si le compteur atteint 30
    if count == 30:
        # Réinitialise le compteur et incrémente l'heure
        count = 0
        heure += 1
    
    # Incrémente le compteur
    count += 1

    # Adresse e-mail du destinataire
    destinataire = f"{i}"

    # Corps du message avec l'heure mise à jour
    corps = f"Dans cette étape, nous vous convions à un entretien de motivation qui aura lieu ce vendredi 29 septembre 2023 à {heure}H00 à la Villa Simplon"
    
    # Création du message MIME
    message = MIMEMultipart()
    message["From"] = expediteur
    message["To"] = destinataire
    message["Subject"] = sujet
    
    # Ajout du corps du message
    message.attach(MIMEText(corps, "plain")) 
    
    # Pièce jointe PDF
    piece_jointe = "AWS1.pdf"
    with open(piece_jointe, encoding="utf-8", errors='ignore') as fichier_pdf:
        pdf = MIMEApplication(fichier_pdf.read(), _subtype="pdf")
        pdf.add_header("content-disposition", "attachment", filename="test en ligne aws.pdf")
        message.attach(pdf)
   
    # Configuration du serveur SMTP de Gmail
    serveur_smtp = smtplib.SMTP("smtp.gmail.com", 587)
    serveur_smtp.starttls()
    
    # Connexion au compte expéditeur
    serveur_smtp.login(expediteur, mot_de_passe)
    try:
        # Envoi de l'e-mail
        serveur_smtp.sendmail(expediteur, destinataire, message.as_string())
        print(f"L'e-mail a été envoyé à {destinataire} avec succès.")
    except Exception as e:
        print(f"Erreur lors de l'envoi de l'e-mail à {destinataire}: {str(e)}")

# Fermeture de la connexion SMTP
serveur_smtp.quit()
